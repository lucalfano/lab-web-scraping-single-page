# %% [markdown]
# # Lab | Web Scraping Single Page

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import random
from time import sleep

# %%
# get 100 sonfs, into pd df
# fopr morning

# %%
# get input,
# if songs not there have a rejection

# %%
url = 'https://www.popvortex.com/music/charts/top-100-songs.php'

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><title>iTunes Top 100 Songs Chart 2022</title><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="description" content="iTunes top 100 songs chart list. The most popular hit music and trending songs of 2022. Chart of today\'s current iTunes top 100 songs is updated daily."><meta property="og:title" content="iTunes Top 100 Songs Chart 2022"/><meta property="og:description" content="Chart of the top 100 songs on iTunes. Chart list of the top 100 song downloads of 2022 is updated daily."/><meta property="og:type" content="article"/><meta property="og:image" content="https://www.popvortex.com/images/logo-facebook.png"/><meta property="og:site_name" content="PopVortex"/><meta property="og:url" content="https://www.popvortex.com/music/charts/top-100-songs.php"/><meta property="fb:admins" content="100000239962942"/><meta property="fb:app_id" content="178831188827052"/><link rel="shortcut icon" href="/fa
# ...

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    iTunes Top 100 Songs Chart 2022
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="iTunes top 100 songs chart list. The most popular hit music and trending songs of 2022. Chart of today's current iTunes top 100 songs is updated daily." name="description"/>
#   <meta content="iTunes Top 100 Songs Chart 2022" property="og:title">
#    <meta content="Chart of the top 100 songs on iTunes. Chart list of the top 100 song downloads of 2022 is updated daily." property="og:description">
#     <meta content="article" property="og:type">
#      <meta content="https://www.popvortex.com/images/logo-facebook.png" property="og:image"/>
#      <meta content="PopVortex" property="og:site_name"/>
#      <meta content="https://www.popvortex.com/music/charts/top-100-songs.php" property="og:url"/>
#      <meta content="100000239962942" property="fb:admins"/>
# ...

# %%
#chart-position-1
#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > cite

#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p

# %%
soup.select('cite')
# Out:
# [<cite class="title">Unholy</cite>,
#  <cite class="title">Everywhere</cite>,
#  <cite class="title">Eagle (feat. KB)</cite>,
#  <cite class="title">I'm Good (Blue)</cite>,
#  <cite class="title">A Thousand Years</cite>,
#  <cite class="title">wait in the truck</cite>,
#  <cite class="title">Thank God</cite>,
#  <cite class="title">Son Of A Sinner</cite>,
#  <cite class="title">You Proof</cite>,
#  <cite class="title">I Ain't Worried</cite>,
#  <cite class="title">Unstoppable</cite>,
#  <cite class="title">CUFF IT</cite>,
#  <cite class="title">Left and Right</cite>,
#  <cite class="title">Bedroom Singer</cite>,
#  <cite class="title">Wasted On You</cite>,
#  <cite class="title">She Had Me At Heads Carolina</cite>,
#  <cite class="title">As It Was</cite>,
#  <cite>Billboard Hot 100</cite>,
#  <cite class="title">Fall In Love</cite>,
#  <cite class="title">Under the Influence</cite>,
#  <cite class="title">Lose Yourself</cite>,
#  <cite class="title">The Kind of Love We Make</cite>,
# ...

# %%
soup.select('cite.title')[0].get_text()
# Out:
# 'Unholy'

# %%
#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > em

# %%
soup.select('em')
# Out:
# [<em class="artist">Sam Smith &amp; Kim Petras</em>,
#  <em class="artist">Fleetwood Mac</em>,
#  <em class="artist">Transformation Worship</em>,
#  <em>New Release</em>,
#  <em class="artist">David Guetta &amp; Bebe Rexha</em>,
#  <em class="artist">Christina Perri</em>,
#  <em class="artist">HARDY &amp; Lainey Wilson</em>,
#  <em class="artist">Kane Brown &amp; Katelyn Brown</em>,
#  <em class="artist">Jelly Roll</em>,
#  <em class="artist">Morgan Wallen</em>,
#  <em class="artist">OneRepublic</em>,
#  <em class="artist">Sia</em>,
#  <em class="artist">Beyoncé</em>,
#  <em class="artist">Charlie Puth &amp; Jung Kook</em>,
#  <em class="artist">J.Fla</em>,
#  <em>New Release</em>,
#  <em class="artist">Morgan Wallen</em>,
#  <em class="artist">Cole Swindell</em>,
#  <em class="artist">Harry Styles</em>,
#  <em class="artist">Bailey Zimmerman</em>,
#  <em class="artist">Chris Brown</em>,
#  <em class="artist">Eminem</em>,
#  <em class="artist">Luke Combs</em>,
# ...

# %%
soup.select('em.artist')[0].get_text()
# Out:
# 'Sam Smith & Kim Petras'

# %%
soup.select('p.chart-position')[0].get_text()
# Out:
# '1'

# %%
# will's
# #initialize empty lists
# title = []
# artist = []
# rank = []

# # Number of iterations
# num_iter = len(soup.select("cite.title"))

# # Setting up what to iterate for each empty list
# t_list = soup.select("cite.title")
# a_list = soup.select("em.artist")
# chart_rank = soup.select('p.chart-position')

# # iterate through the result set and retrive all the data
# for i in range(num_iter):
#     title.append(t_list[i].get_text())
#     artist.append(a_list[i].get_text())
#     rank.append(chart_rank[i].get_text())

# # Checking results
# print(title)
# print(artist)
# print(rank)

# %%
title = []
artist = []
rank = []

num_iter = len(soup.select('cite.title'))

tlist = soup.select('cite.title')
alist = soup.select('em.artist')
chart = soup.select('p.chart-position')

for i in range(num_iter):
    title.append(tlist[i].get_text())
    artist.append(alist[i].get_text())
    rank.append(chart[i].get_text())
    
# #print(title)
# #print(artist)
# #print(rank)

# %%
top100 = pd.DataFrame({'title':title,
                       'artist':artist,
                       'rank':rank})

# %%
top100
# Out:
#                         title  \
# 0                      Unholy
# 1                  Everywhere
# 2            Eagle (feat. KB)
# 3             I'm Good (Blue)
# 4            A Thousand Years
# ..                        ...
# 95                    Save Me
# 96               Annie's Song
# 97             Lady Marmalade
# 98             'Til You Can't
# 99  We Don't Talk About Bruno
#
#                                                artist rank
# 0                              Sam Smith & Kim Petras    1
# 1                                       Fleetwood Mac    2
# 2                              Transformation Worship    3
# 3                           David Guetta & Bebe Rexha    4
# 4                                     Christina Perri    5
# ..                                                ...  ...
# 95                                         Jelly Roll   96
# 96                                        John Denver   97
# 97           Christina Aguilera, Lil' Kim, Mýa & P!nk   98
# ...

# %%
songs = top100.copy()

# %%
# Genre stuff

# %%
soup.select('#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > ul > li:nth-child(1) > a')[0].get_text()
# Out:
# 'Pop'

# %%
# title = []
# artist = []
# rank = []
# genre = []

# num_iter = len(soup.select('cite.title'))

# tlist = soup.select('cite.title')
# alist = soup.select('em.artist')
# chart = soup.select('p.chart-position')
# genre = soup.select('#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > ul > li:nth-child(1) > a')

# for i in range(num_iter):
#     title.append(tlist[i].get_text())
#     artist.append(alist[i].get_text())
#     rank.append(chart[i].get_text())
#     genre.append(genre[i].get_text())
    
# print(title)
# print(artist)
# print(rank)
# print(genre)

# %%
# top100 = pd.DataFrame({'title':title,
#                        'artist':artist,
#                        'rank':rank,
#                        'genre':genre})

# %%
#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > ul > li:nth-child(1) > a

# %%
print('Welcome to Gnod song recommender, enter your favorite song:')

str(input())

rand_idx = random.randrange(len(top100['title']))
                            
random_rec = title[rand_idx]

print('we recommend this song: ' + random_rec)
# Out:
# Welcome to Gnod song recommender, enter your favorite song:
# l
# we recommend this song: As It Was

# %% [markdown]
# # Lab | Web Scraping Multiple Pages

# %%
url = 'https://www.popvortex.com/music/itunes-charts/top-100-songs-uk.php'

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><title>iTunes UK Top 100 Songs</title><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="description" content="iTunes top 100 songs in Australia. Chart countdown of today\'s most popular music downloads at Australia\'s iTunes music store. Chart of the  current Austalian top 100 hit songs is updated daily."><meta property="og:title" content="iTunes UK Top 100 Songs"/><meta property="og:description" content="iTunes top 100 songs in Australia. Chart countdown of today\'s most popular music downloads at Australia\'s iTunes music store. Chart of the  current Austalian top 100 hit songs is updated daily."/><meta property="og:type" content="article"/><meta property="og:image" content="https://www.popvortex.com/images/logo-facebook.png"/><meta property="og:site_name" content="PopVortex"/><meta property="og:url" content="https://www.popvortex.com/music/itunes-charts/top-100-songs-uk.php"/><meta property=
# ...

# %%
soup2 = BeautifulSoup(response.content, "html.parser")

# %%
soup2
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    iTunes UK Top 100 Songs
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="iTunes top 100 songs in Australia. Chart countdown of today's most popular music downloads at Australia's iTunes music store. Chart of the  current Austalian top 100 hit songs is updated daily." name="description"/>
#   <meta content="iTunes UK Top 100 Songs" property="og:title">
#    <meta content="iTunes top 100 songs in Australia. Chart countdown of today's most popular music downloads at Australia's iTunes music store. Chart of the  current Austalian top 100 hit songs is updated daily." property="og:description">
#     <meta content="article" property="og:type">
#      <meta content="https://www.popvortex.com/images/logo-facebook.png" property="og:image"/>
#      <meta content="PopVortex" property="og:site_name"/>
# ...

# %%
soup2.select('cite')
# Out:
# [<cite class="title">I'm Good (Blue)</cite>,
#  <cite class="title">Unholy</cite>,
#  <cite class="title">Celestial</cite>,
#  <cite class="title">Forget Me</cite>,
#  <cite class="title">B.O.T.A. (Baddest Of Them All) [Edit]</cite>,
#  <cite class="title">All For You</cite>,
#  <cite class="title">CUFF IT</cite>,
#  <cite class="title">2 Be Loved (Am I Ready)</cite>,
#  <cite class="title">PSYCHO</cite>,
#  <cite class="title">I Ain't Worried</cite>,
#  <cite class="title">Don’t Let The Light Go Out</cite>,
#  <cite class="title">Turn On The Lights again.. (feat. Future)</cite>,
#  <cite class="title">Super Freaky Girl</cite>,
#  <cite>Billboard Hot 100</cite>,
#  <cite class="title">Three Dads Walking</cite>,
#  <cite class="title">All These Nights</cite>,
#  <cite class="title">As It Was</cite>,
#  <cite>Billboard Hot 100</cite>,
#  <cite class="title">Big City Life</cite>,
#  <cite class="title">Hold My Hand</cite>,
#  <cite class="title">Hold Me Closer</cite>,
# ...

# %%
soup2.select('cite.title')[0].get_text()
# Out:
# "I'm Good (Blue)"

# %%
soup2.select('em')
# Out:
# [<em class="artist">David Guetta &amp; Bebe Rexha</em>,
#  <em class="artist">Sam Smith &amp; Kim Petras</em>,
#  <em class="artist">Ed Sheeran</em>,
#  <em class="artist">Lewis Capaldi</em>,
#  <em class="artist">Eliza Rose &amp; Interplanetary Criminal</em>,
#  <em class="artist">Cian Ducrot &amp; Ella Henderson</em>,
#  <em class="artist">Beyoncé</em>,
#  <em class="artist">Lizzo</em>,
#  <em class="artist">Anne-Marie x Aitch</em>,
#  <em class="artist">OneRepublic</em>,
#  <em class="artist">Panic! At the Disco</em>,
#  <em class="artist">Fred again.. &amp; Swedish House Mafia</em>,
#  <em class="artist">Nicki Minaj</em>,
#  <em class="artist">The Young'uns</em>,
#  <em>New Release</em>,
#  <em class="artist">Tom Grennan</em>,
#  <em class="artist">Harry Styles</em>,
#  <em class="artist">Luude &amp; Mattafix</em>,
#  <em class="artist">Lady Gaga</em>,
#  <em class="artist">Elton John &amp; Britney Spears</em>,
#  <em class="artist">Adam Lambert</em>,
#  <em>New Release</em>,
# ...

# %%
soup2.select('em.artist')[0].get_text()
# Out:
# 'David Guetta & Bebe Rexha'

# %%
soup2.select('p.chart-position')[0].get_text()
# Out:
# '1'

# %%
titleuk = []
artistuk = []

num_iteruk = len(soup2.select('cite.title'))

tlistuk = soup2.select('cite.title')
alistuk = soup2.select('em.artist')

for i in range(num_iter):
    titleuk.append(tlistuk[i].get_text())
    artistuk.append(alistuk[i].get_text())
    
# #print(title)
# #print(artist)
# #print(rank)

# %%
top100uk = pd.DataFrame({'title':titleuk,
                       'artist':artistuk
                       })

# %%
top100uk
# Out:
#                                     title  \
# 0                         I'm Good (Blue)
# 1                                  Unholy
# 2                               Celestial
# 3                               Forget Me
# 4   B.O.T.A. (Baddest Of Them All) [Edit]
# ..                                    ...
# 95                              Wide Eyes
# 96                                Shotgun
# 97                                 Linger
# 98           I Don't Want to Miss a Thing
# 99                            Danger Zone
#
#                                   artist
# 0              David Guetta & Bebe Rexha
# 1                 Sam Smith & Kim Petras
# 2                             Ed Sheeran
# 3                          Lewis Capaldi
# 4   Eliza Rose & Interplanetary Criminal
# ..                                   ...
# 95                          The Big Moon
# 96                           George Ezra
# 97                       The Cranberries
# ...

# %% [markdown]
# # func for multi

# %%
def scraper(url):

    response3 = requests.get(url)
    soup3 = BeautifulSoup(response3.content, "html.parser")

    titles = []
    artists = []

    num_iters = len(soup3.select("cite.title"))

    t_lists = soup3.select("cite.title")
    a_lists = soup3.select("em.artist")

    for i in range(num_iters):
        titles.append(t_lists[i].get_text())
        artists.append(a_lists[i].get_text())
    
    test = pd.DataFrame({"title":titles,
                       "artist":artists})
    return test

# %%
urls1 = 'https://www.popvortex.com/music/france/top-songs.php'
urls2 = 'https://www.popvortex.com/music/charts/top-100-songs.php'

france_100 = scraper(urls1)
us_100 = scraper(urls2)

# %%
songs_list = pd.concat([france_100, us_100], axis=0).reset_index(drop=True)

songs_list
