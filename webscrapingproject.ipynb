# %% [markdown]
# # Lab | Web Scraping Single Page

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import random
from time import sleep

# %%
# get 100 sonfs, into pd df
# fopr morning

# %%
# get input,
# if songs not there have a rejection

# %%
url = 'https://www.popvortex.com/music/charts/top-100-songs.php'

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
# response.content

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
# soup

# %%
# print(soup.prettify())

# %%
#chart-position-1
#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > cite

#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p

# %%
# soup.select('cite')

# %%
# soup.select('cite.title')[0].get_text()

# %%
#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > em

# %%
# soup.select('em')

# %%
# soup.select('em.artist')[0].get_text()

# %%
# soup.select('p.chart-position')[0].get_text()

# %%
# will's
# #initialize empty lists
# title = []
# artist = []
# rank = []

# # Number of iterations
# num_iter = len(soup.select("cite.title"))

# # Setting up what to iterate for each empty list
# t_list = soup.select("cite.title")
# a_list = soup.select("em.artist")
# chart_rank = soup.select('p.chart-position')

# # iterate through the result set and retrive all the data
# for i in range(num_iter):
#     title.append(t_list[i].get_text())
#     artist.append(a_list[i].get_text())
#     rank.append(chart_rank[i].get_text())

# # Checking results
# print(title)
# print(artist)
# print(rank)

# %%
title = []
artist = []
rank = []

num_iter = len(soup.select('cite.title'))

tlist = soup.select('cite.title')
alist = soup.select('em.artist')
chart = soup.select('p.chart-position')

for i in range(num_iter):
    title.append(tlist[i].get_text())
    artist.append(alist[i].get_text())
    rank.append(chart[i].get_text())
    
# #print(title)
# #print(artist)
# #print(rank)

# %%
top100 = pd.DataFrame({'title':title,
                       'artist':artist,
                       'rank':rank})

# %%
top100
# Out:
#                         title                        artist rank
# 0                      Unholy        Sam Smith & Kim Petras    1
# 1             I'm Good (Blue)     David Guetta & Bebe Rexha    2
# 2                   Thank God    Kane Brown & Katelyn Brown    3
# 3           wait in the truck         HARDY & Lainey Wilson    4
# 4               Face It Alone                         Queen    5
# ..                        ...                           ...  ...
# 95           Everything I Own                         Bread   96
# 96            Me Porto Bonito  Bad Bunny & Chencho Corleone   97
# 97           Wishful Drinking     Ingrid Andress & Sam Hunt   98
# 98                     Enough             charlieonnafriday   99
# 99  You Should Probably Leave               Chris Stapleton  100
#
# [100 rows x 3 columns]

# %%
top100copy = top100.copy()

# %%
# Genre stuff

# %%
soup.select('#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > ul > li:nth-child(1) > a')[0].get_text()
# Out:
# 'Pop'

# %%
# title = []
# artist = []
# rank = []
# genre = []

# num_iter = len(soup.select('cite.title'))

# tlist = soup.select('cite.title')
# alist = soup.select('em.artist')
# chart = soup.select('p.chart-position')
# genre = soup.select('#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > ul > li:nth-child(1) > a')

# for i in range(num_iter):
#     title.append(tlist[i].get_text())
#     artist.append(alist[i].get_text())
#     rank.append(chart[i].get_text())
#     genre.append(genre[i].get_text())
    
# print(title)
# print(artist)
# print(rank)
# print(genre)

# %%
# top100 = pd.DataFrame({'title':title,
#                        'artist':artist,
#                        'rank':rank,
#                        'genre':genre})

# %%
#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > ul > li:nth-child(1) > a

# %%
print('Welcome to Gnod song recommender, enter your favorite song:')

str(input())

rand_idx = random.randrange(len(top100['title']))
                            
random_rec = title[rand_idx]

print('we recommend this song: ' + random_rec)
# Out:
# Welcome to Gnod song recommender, enter your favorite song:
# l
# we recommend this song: Eagle (feat. KB)

# %% [markdown]
# # Lab | Web Scraping Multiple Pages

# %%
url = 'https://www.popvortex.com/music/itunes-charts/top-100-songs-uk.php'

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
# response.content

# %%
soup2 = BeautifulSoup(response.content, "html.parser")

# %%
# soup2

# %%
# print(soup2.prettify())

# %%
# soup2.select('cite')

# %%
# soup2.select('cite.title')[0].get_text()

# %%
# soup2.select('em')

# %%
# soup2.select('em.artist')[0].get_text()

# %%
soup2.select('p.chart-position')[0].get_text()
# Out:
# '1'

# %%
titleuk = []
artistuk = []

num_iteruk = len(soup2.select('cite.title'))

tlistuk = soup2.select('cite.title')
alistuk = soup2.select('em.artist')

for i in range(num_iter):
    titleuk.append(tlistuk[i].get_text())
    artistuk.append(alistuk[i].get_text())
    
# #print(title)
# #print(artist)
# #print(rank)

# %%
top100uk = pd.DataFrame({'title':titleuk,
                       'artist':artistuk
                       })

# %%
top100uk
# Out:
#                                         title                     artist
# 0                               Face It Alone                      Queen
# 1                             Celtic Symphony            The Wolfe Tones
# 2                             I'm Good (Blue)  David Guetta & Bebe Rexha
# 3                                      Unholy     Sam Smith & Kim Petras
# 4                                   Forget Me              Lewis Capaldi
# ..                                        ...                        ...
# 95                             BILLIE EILISH.               Armani White
# 96  Cure My Desire (feat. Clementine Douglas)               Hannah Wants
# 97                              Love Yourself        The Lottery Winners
# 98                          This Is Your Life                  Una Healy
# 99                        A Sky Full of Stars                   Coldplay
#
# [100 rows x 2 columns]

# %% [markdown]
# # func for multi

# %%
# def scraper(url):

#     response3 = requests.get(url)
#     soup3 = BeautifulSoup(response3.content, "html.parser")

#     titles = []
#     artists = []

#     num_iters = len(soup3.select("cite.title"))

#     t_lists = soup3.select("cite.title")
#     a_lists = soup3.select("em.artist")

#     for i in range(num_iters):
#         titles.append(t_lists[i].get_text())
#         artists.append(a_lists[i].get_text())
    
#     test = pd.DataFrame({"title":titles,
#                        "artist":artists})
#     return test

# %%
# urls1 = 'https://www.popvortex.com/music/france/top-songs.php'
# urls2 = 'https://www.popvortex.com/music/charts/top-100-songs.php'

# france_100 = scraper(urls1)
# us_100 = scraper(urls2)

# %%
# songs_list = pd.concat([france_100, us_100], axis=0).reset_index(drop=True)

# songs_list

# %% [markdown]
# # Spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("/Users/lucaalfano/IH-labs/secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
# secrets_dict

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)     #open and read the first page 
    tracks = results['items']              #all the tracks in all the pages, long list of tracks assigning the items(actual songs) 
    while results['next']!=None:          #while next is not none, read the next page, check if its none then continue, loop is executed while the condition is true 
        results = sp.next(results)       #add the ocntents of this list to the list we alrady had 
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000)
    return tracks

# %%
# this will take at least around num_songs_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

# all_tracks = get_playlist_tracks("5S8SJdl1BDc0ugpkEvFsIL")
# len(all_tracks)

# %%
# all_tracks

# %%
# all_tracks[0]

# %%
# all_tracks[1]

# %%
# all_tracks[1].keys()

# %%
# all_tracks[1]['track']

# %%
# all_tracks[1]['track']['name']

# %%
# all_tracks[1]['track']['artists']

# %%
# all_tracks[1]['track']['artists'][0]['name']

# %%
# for a in range(len(all_tracks)):
#     print(all_tracks[a]['track']['artists'][0]['name'])

# %%
# all_tracks[1]['track']['name']

# %%
# track = []

# for a in range(len(all_tracks)-1):
#     adding = all_tracks[a]['track']['name']
#     track.append(adding)

# %%
# track

# %%
# artists = []

# for a in range(len(all_tracks)-1):
#     insert = all_tracks[a]['track']['artists'][0]['name']
#     artists.append(insert)

# %%
# all_tracks[1]['track']['uri']

# %%
# all_tracks[1]['track']['uri'].split(':')

# %%
# uri = []

# for a in range(len(all_tracks)):
#     adding = all_tracks[a]['track']['uri']
#     uri.append(adding)

# %%
# uri

# %%
# all_tracks[1]['track']['uri']

# %%
# sp.audio_features(uri)

# %%
# for i in range(len(uri)):
#     squish_uri = sp.audio_features(uri[i])

# %%
# sp.audio_features(all_tracks[0]["track"]["uri"])

# %%
# def features(tracks):
    
#     song_features = {}
    
#     for i in range(10):
#         song_features[tracks[i]['track']['id']] = sp.audio_features(tracks[i]["track"]["uri"])
    
#     return song_features

# %%
# features(all_tracks)

# %%
# def features2(tracks):
    
#     song_features = {}
    
#     for i in range(len(all_tracks)):
#         song_features[tracks[i]['track']['id']] = sp.audio_features(tracks[i]["track"]["uri"])
    
#     return song_features

# %%
# features2(all_tracks)

# %%
# uris = features2(all_tracks)

# %%
# uris

# %%
# import pandas as pd
# dict(uris)
# pd.DataFrame(dict(uris))
# uri_df = pd.DataFrame(dict(uris)).transpose()

# uri_df

# %%
# uri_df.rename(columns = {0:'audio_features'}, inplace = True)

# uri_df = uri_df.reset_index(drop=True)

# uri_df

# %%
def flatten_dict(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
# uri_df_final = flatten_dict(uri_df, ['audio_features'])

# %%
# uri_df_final
# drop some cat columns

# %%
# uri_df_final = uri_df_final.drop(['audio_features_type', 'audio_features_id', 'audio_features_uri', 'audio_features_track_href', 'audio_features_analysis_url'], axis=1)

# %%
# df_concat = pd.DataFrame({'artist':artists,
#                          'track':track,
#                          })

# %%
# uri_df_final.reset_index(drop=True, inplace=True)
# df_concat.reset_index(drop=True, inplace=True)

# %%
# songs = pd.concat([df_concat, uri_df_final], axis=1)

# %%
# songs

# %%
# songs.isna().sum()

# %%
# songs = songs.dropna()

# %%
# songs.isna().sum()

# %%
# songs

# %%
# songs.to_csv('songs.csv', index=False)

# %%
# end

# %%
display = pd.read_csv('songs.csv')

# %%
display
# Out:
#                              artist  \
# 0                      Taylor Swift
# 1                      Thomas Rhett
# 2                        Bruno Mars
# 3                        Ed Sheeran
# 4                        Ed Sheeran
# ...                             ...
# 9939        Wolfgang Amadeus Mozart
# 9940               Echoes Of Nature
# 9941                   Chris Butler
# 9942       Pyotr Ilyich Tchaikovsky
# 9943  Bluecoats Drum and Bugle Corp
#
#                                                   track  \
# 0                                      ...Ready For It?
# 1                                          Life Changes
# 2                                             24K Magic
# 3                                           Galway Girl
# 4                                            Photograph
# ...                                                 ...
# 9939  Piano Concerto No. 26 in D Major, K. 537, "Cor...
# 9940                                       Pebble Beach
# ...

# %%
# importing more songs from a csv, as this has been a nightmare that i've barely understood

# %%
songs2 = pd.read_csv('SpotifyAudioFeaturesApril2019.csv')

# %%
# songs2

# %%
songs3 = pd.read_csv('SpotifyAudioFeaturesNov2018.csv')

# %%
# songs3

# %%
finalsongs = pd.concat([songs2,songs3], axis=0)

# %%
# finalsongs

# %%
finalsongs = finalsongs.drop(['track_id'],axis=1)

# %%
# finalsongs

# %%
forcluster = finalsongs.drop(['artist_name', 'track_name'],axis=1)
forcluster
# Out:
#         acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0           0.005820         0.743       238373   0.339            0.0000
# 1           0.024400         0.846       214800   0.557            0.0000
# 2           0.025000         0.603       138913   0.723            0.0000
# 3           0.029400         0.800       125381   0.579            0.9120
# 4           0.000035         0.783       124016   0.792            0.8780
# ...              ...           ...          ...     ...               ...
# 116367      0.978000         0.103       245714   0.086            0.9630
# 116368      0.099200         0.674       221934   0.628            0.0000
# 116369      0.027700         0.792       183771   0.747            0.0000
# 116370      0.067500         0.548       311267   0.506            0.0244
# 116371      0.472000         0.785       106500   0.145            0.9400
#
#         key  liveness  loudness  mode  speechiness    tempo  time_signature  \
# ...

# %% [markdown]
# # Clustering

# %%
X = forcluster


# Comment the different variables of this dataset
# Notice how they are all numerical - KMeans cannot deal with categorical variables
X.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0      0.005820         0.743       238373   0.339             0.000    1
# 1      0.024400         0.846       214800   0.557             0.000    8
# 2      0.025000         0.603       138913   0.723             0.000    9
# 3      0.029400         0.800       125381   0.579             0.912    5
# 4      0.000035         0.783       124016   0.792             0.878    7
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.0812    -7.678     1       0.4090  203.927               4    0.118
# 1    0.2860    -7.259     1       0.4570  159.009               4    0.371
# 2    0.0824    -5.890     0       0.0454  114.966               4    0.382
# 3    0.0994   -12.118     0       0.0701  123.003               4    0.641
# 4    0.0332   -10.277     1       0.0661  120.047               4    0.928
#
#    popularity
# 0          15
# 1           0
# 2          56
# ...

# %%
from sklearn.preprocessing import StandardScaler
X_prep = StandardScaler().fit_transform(X)

# Now, all features will have the same weight.
pd.DataFrame(X_prep,columns=X.columns).head()
# Out:
#    acousticness  danceability  duration_ms    energy  instrumentalness  \
# 0     -0.967840      0.847761     0.208406 -0.891887         -0.627144
# 1     -0.913898      1.389927     0.017848 -0.051779         -0.627144
# 2     -0.912156      0.110837    -0.595603  0.587937         -0.627144
# 3     -0.899382      1.147795    -0.704992  0.033003          1.893636
# 4     -0.984634      1.058311    -0.716027  0.853843          1.799660
#
#         key  liveness  loudness      mode  speechiness     tempo  \
# 0 -1.175507 -0.676495  0.349757  0.803557     2.387536  2.798539
# 1  0.767176  0.545674  0.413968  0.803557     2.773536  1.309009
# 2  1.044702 -0.669334  0.623767 -1.244467    -0.536413 -0.151506
# 3 -0.065403 -0.567884 -0.330673 -1.244467    -0.337784  0.115010
# 4  0.489650 -0.962941 -0.048540  0.803557    -0.369951  0.016986
#
#    time_signature   valence  popularity
# 0        0.232811 -1.238092   -0.488029
# 1        0.232811 -0.262420   -1.281892
# ...

# %%
X_prep
# Out:
# array([[-0.96783975,  0.84776146,  0.20840563, ...,  0.2328108 ,
#         -1.23809235, -0.4880289 ],
#        [-0.91389819,  1.38992707,  0.01784761, ...,  0.2328108 ,
#         -0.26241963, -1.28189192],
#        [-0.91215627,  0.11083733, -0.59560322, ...,  0.2328108 ,
#         -0.21999908,  1.68186335],
#        ...,
#        [-0.90431761,  1.1056849 , -0.23298278, ...,  0.2328108 ,
#          0.55899653,  1.20554554],
#        [-0.78877002, -0.17866858,  0.79766183, ...,  0.2328108 ,
#         -0.64806102,  1.36431815],
#        [ 0.38557676,  1.0688387 , -0.85762151, ...,  0.2328108 ,
#         -0.02332197,  1.47016655]])

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10, random_state=1234)
kmeans.fit(X_prep)
# Out:
# KMeans(n_clusters=10, random_state=1234)

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(X_prep)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    21630
# 1    36711
# 2    28126
# 3      211
# 4     3809
# 5    27483
# 6    50976
# 7    35181
# 8    29088
# 9    13820
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
plt.scatter(X_prep[:, 0], X_prep[:, 4], c=clusters,alpha=0.5)
plt.show()

# %%
# %%time
import numpy as np
from sklearn.cluster import KMeans


K = range(2, 15)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# CPU times: user 2min 59s, sys: 25.4 s, total: 3min 25s
# Wall time: 29 s
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
# %%time
from sklearn.metrics import silhouette_score
K = range(2, 15)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')
# Out:
# CPU times: user 3h 1min 45s, sys: 56min 30s, total: 3h 58min 15s
# Wall time: 2h 5min 35s
# Text(0.5, 1.0, 'Slhouette score showing the optimal k')

# %%
# silhoutte runs forever and never outputs anything

# %%
# %%time
kmeans = KMeans(n_clusters=10,
                init="random",
                n_init=100,  
                max_iter=10,
                tol=0,
                random_state=1234)
kmeans.fit(X_prep)
print(kmeans.inertia_)

# %%
# Predicting / assigning the clusters:
# clusters = kmeans.predict(X_prep)

# Check the size of the clusters
# pd.Series(clusters).value_counts().sort_index()

# %%
# kmeans.inertia

# %%
# finalsongs['cluster'] = kmeans.fit_predict(X_prep)
# maybe not sure
